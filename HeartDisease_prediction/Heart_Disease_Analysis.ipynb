# %% [markdown]
# ## **Heart Disease Prediction**
# A project that contains requirements through which we can analyze heart diseases types, blood pressure and other informations

# %% [markdown]
# ### Libraries

# %%
# Importing Libraries

import numpy as np
import pandas as pd

# %% [markdown]
# ### Dataset

# %%
ht = pd.read_csv('D:/Machine Learning Bootcamp/Datasets/heart_disease_uci.csv')
ht
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# ### Top rows

# %%
# Displaying top 6 rows 
ht.head(6)
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5   6   56    Male  Cleveland  atypical angina     120.0  236.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
# 5          normal   178.0  False      0.8    upsloping  0.0
#
#                 thal  num
# ...

# %% [markdown]
# ### Last rows

# %%
# Displaying last 6 rows
ht.tail(6)
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 914  915   46    Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 914            normal   126.0  False      0.0   NaN NaN        normal    2
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# ...

# %% [markdown]
# ### Datatypes

# %%
# For datatype of each column
ht.dtypes
# Out:
# id            int64
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch      float64
# exang        object
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# num           int64
# dtype: object

# %% [markdown]
# ### Information Of Dataset
# Statistical Summary:

# %%
# Getting complete information of the datasset
ht.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %% [markdown]
# This shows the complete detail about the dataset, i.e. each column's name, no. of rows, null values, and its datatype

# %%
# Description
ht.describe
# Out:
# <bound method NDFrame.describe of       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# A descriptive dataset will be shown

# %% [markdown]
# ### Number Of Rows

# %%
# Checking length of rows
len(ht)
# Out:
# 920

# %% [markdown]
# ### Number of Columns

# %%
# Checking number of columns in dataset
ht.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
# Checking length of columns
len(ht.columns)
# Out:
# 16

# %% [markdown]
# ### Null Values

# %%
# For checking null values in the dataset
ht.isnull()
# Out:
#         id    age    sex  dataset     cp  trestbps   chol    fbs  restecg  \
# 0    False  False  False    False  False     False  False  False    False
# 1    False  False  False    False  False     False  False  False    False
# 2    False  False  False    False  False     False  False  False    False
# 3    False  False  False    False  False     False  False  False    False
# 4    False  False  False    False  False     False  False  False    False
# ..     ...    ...    ...      ...    ...       ...    ...    ...      ...
# 915  False  False  False    False  False     False  False  False    False
# 916  False  False  False    False  False      True  False  False    False
# 917  False  False  False    False  False     False  False  False    False
# 918  False  False  False    False  False      True  False  False    False
# 919  False  False  False    False  False     False  False  False    False
#
#      thalch  exang  oldpeak  slope     ca   thal    num
# ...

# %% [markdown]
# True shows that there is null value available in the dataset

# %% [markdown]
# ### Null Values for Categories

# %%
# Checking null values for each column in boolean
ht.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %% [markdown]
# ### Solving Null Values Given As NaN In "trestbps"

# %%
# Finding Nan values
bool_series = pd.notnull(ht["trestbps"])
ht[bool_series]
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 913  914   62    Male  VA Long Beach     asymptomatic     158.0  170.0  False
# 914  915   46    Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# Filling Nan values
ht["trestbps"].fillna("trestbps", inplace = True)
ht
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina  trestbps  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic  trestbps  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# ### Specifying The Column Of "trestbps"

# %%
ht['trestbps']
# Out:
# 0         145.0
# 1         160.0
# 2         120.0
# 3         130.0
# 4         130.0
#          ...
# 915       127.0
# 916    trestbps
# 917       122.0
# 918    trestbps
# 919       120.0
# Name: trestbps, Length: 920, dtype: object

# %% [markdown]
# #### Max Value

# %%
# To find the max value of above specific column
ht['trestbps'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0         145.0
# 1         160.0
# 2         120.0
# 3         130.0
# 4         130.0
#          ...
# 915       127.0
# 916    trestbps
# 917       122.0
# 918    trestbps
# 919       120.0
# Name: trestbps, Length: 920, dtype: object>

# %% [markdown]
# #### Min Value

# %%
# To find the min value of above specific column
ht['trestbps'].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0         145.0
# 1         160.0
# 2         120.0
# 3         130.0
# 4         130.0
#          ...
# 915       127.0
# 916    trestbps
# 917       122.0
# 918    trestbps
# 919       120.0
# Name: trestbps, Length: 920, dtype: object>

# %% [markdown]
# ### Mean Value

# %%
# To find the average value of above specific column
ht['trestbps'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0         145.0
# 1         160.0
# 2         120.0
# 3         130.0
# 4         130.0
#          ...
# 915       127.0
# 916    trestbps
# 917       122.0
# 918    trestbps
# 919       120.0
# Name: trestbps, Length: 920, dtype: object>

# %% [markdown]
# ### Gender Analysis

# %%
# How many people having sex = male are heart patiest
ht['sex']=='Male'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 915    False
# 916     True
# 917     True
# 918     True
# 919     True
# Name: sex, Length: 920, dtype: bool

# %%
# Dataset showing only information of male
ht[ht['sex']=='Male']
# Out:
#       id  age   sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63  Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67  Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67  Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37  Male      Cleveland      non-anginal     130.0  250.0  False
# 5      6   56  Male      Cleveland  atypical angina     120.0  236.0  False
# ..   ...  ...   ...            ...              ...       ...    ...    ...
# 914  915   46  Male  VA Long Beach     asymptomatic     134.0  310.0  False
# 916  917   62  Male  VA Long Beach   typical angina  trestbps  139.0  False
# 917  918   55  Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58  Male  VA Long Beach     asymptomatic  trestbps  385.0   True
# 919  920   62  Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# Length of data with sex = male
len(ht[ht['sex']=='Male'])
# Out:
# 726

# %%
# Other method to count length
ht[ht['sex']=='Male'].count()
# Out:
# id          726
# age         726
# sex         726
# dataset     726
# cp          726
# trestbps    726
# chol        703
# fbs         647
# restecg     724
# thalch      673
# exang       673
# oldpeak     665
# slope       478
# ca          212
# thal        323
# num         726
# dtype: int64

# %%
# Visualization for Gender
ht.groupby('sex')['num'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ### Chest Pain Analysis

# %%
# Identifying Chest pain type
ht['cp']
# Out:
# 0       typical angina
# 1         asymptomatic
# 2         asymptomatic
# 3          non-anginal
# 4      atypical angina
#             ...
# 915       asymptomatic
# 916     typical angina
# 917       asymptomatic
# 918       asymptomatic
# 919    atypical angina
# Name: cp, Length: 920, dtype: object

# %%
# Identifying chest pain (cp) containing 'typical angina'
ht['cp'].str.contains('typical angina')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 915    False
# 916     True
# 917    False
# 918    False
# 919     True
# Name: cp, Length: 920, dtype: bool

# %%
# Shows the 'typical angina' data in the cp section for overall dataset
ht[ht['cp'].str.contains('typical angina', case = False)]
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# 5      6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 11    12   56  Female      Cleveland  atypical angina     140.0  294.0  False
# 13    14   44    Male      Cleveland  atypical angina     120.0  263.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 865  866   54    Male  VA Long Beach  atypical angina  trestbps  182.0  False
# 889  890   57    Male  VA Long Beach  atypical angina     180.0  285.0   True
# 894  895   63    Male  VA Long Beach  atypical angina  trestbps  165.0  False
# 916  917   62    Male  VA Long Beach   typical angina  trestbps  139.0  False
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# Shows length of typical angina cp 
len(ht[ht['cp'].str.contains('typical angina', case = False)])
# Out:
# 220

# %%
ht[ht['cp']=="angina"] ['trestbps']
# Out:
# Series([], Name: trestbps, dtype: object)

# %%
# Visualization for chest pain
ht.groupby('cp')['num'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='cp'>

# %% [markdown]
# ### Age Analysis

# %%
# Find the peoples having age 50+
ht['age'] >= 50
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 915     True
# 916     True
# 917     True
# 918     True
# 919     True
# Name: age, Length: 920, dtype: bool

# %%
# For dataframe
ht[ht['age'] >= 50 ]
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 5      6   56    Male      Cleveland  atypical angina     120.0  236.0  False
# 6      7   62  Female      Cleveland     asymptomatic     140.0  268.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina  trestbps  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic  trestbps  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
# Showing the gender having 50+ age
ht[ht['age'] >= 50 ]['sex']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 5        Male
# 6      Female
#         ...
# 915    Female
# 916      Male
# 917      Male
# 918      Male
# 919      Male
# Name: sex, Length: 628, dtype: object

# %%
# Visualization of Age
ht['age'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Distribution Of Heart Disease

# %%
ht['num'].value_counts(normalize=True) * 100
# Out:
# num
# 0    44.673913
# 1    28.804348
# 2    11.847826
# 3    11.630435
# 4     3.043478
# Name: proportion, dtype: float64

# %% [markdown]
# ### Combination Of Different Columns Data

# %%
# Convert columns to appropriate data types
ht['trestbps'] = pd.to_numeric(ht['trestbps'], errors='coerce')
ht['chol'] = pd.to_numeric(ht['chol'], errors='coerce')

# %%
ht[(ht['cp'] == 'typical angina') & (ht['trestbps'] > 130) & (ht['chol'] > 200)]
# Out:
#       id  age     sex        dataset              cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland  typical angina     145.0  233.0   True
# 21    22   58  Female      Cleveland  typical angina     150.0  283.0   True
# 27    28   66  Female      Cleveland  typical angina     150.0  226.0  False
# 30    31   69  Female      Cleveland  typical angina     140.0  239.0  False
# 124  125   65    Male      Cleveland  typical angina     138.0  282.0   True
# 141  142   59    Male      Cleveland  typical angina     170.0  288.0  False
# 150  151   52    Male      Cleveland  typical angina     152.0  298.0   True
# 182  183   42    Male      Cleveland  typical angina     148.0  244.0  False
# 183  184   59    Male      Cleveland  typical angina     178.0  270.0  False
# 196  197   69    Male      Cleveland  typical angina     160.0  234.0   True
# 199  200   59    Male      Cleveland  typical angina     160.0  273.0  False
# ...

# %%
# Visualization of Blood pressure and cholestrol
ht[['trestbps', 'chol']].plot(kind='bar')
# Out:
# <Axes: >

# %%
# Resting ECG and Maximum Heart Rate
ht.groupby('restecg')['thalch'].mean()
# Out:
# restecg
# lv hypertrophy      143.762431
# normal              137.832707
# st-t abnormality    128.926667
# Name: thalch, dtype: float64

# %%
# Viausalization
ht.groupby('restecg')['thalch'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='restecg'>

# %%
# Exercise-Induced Angina
ht.groupby('exang')['num'].value_counts(normalize=True)
# Out:
# exang  num
# False  0      0.636364
#        1      0.202652
#        2      0.083333
#        3      0.056818
#        4      0.020833
# True   1      0.430267
#        3      0.189911
#        2      0.172107
#        0      0.163205
#        4      0.044510
# Name: proportion, dtype: float64

# %%
# Visualization
ht.groupby('exang')['num'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='exang'>

# %%
# ST Depression and Slope
ht.groupby('slope')['oldpeak'].mean()
# Out:
# slope
# downsloping    2.152381
# flat           1.369855
# upsloping      0.623153
# Name: oldpeak, dtype: float64

# %%
# Visualization
ht.groupby('slope')['oldpeak'].mean().plot(kind='line')
# Out:
# <Axes: xlabel='slope'>

# %%
# Number of Major Vessels and Thalassemia
ht.groupby(['ca', 'thal'])['num'].value_counts(normalize=True)
# Out:
# ca   thal               num
# 0.0  fixed defect       0      0.750000
#                         2      0.250000
#      normal             0      0.886957
#                         1      0.095652
#                         2      0.017391
#      reversable defect  0      0.396226
#                         1      0.320755
#                         3      0.150943
#                         2      0.075472
#                         4      0.056604
# 1.0  fixed defect       1      0.500000
#                         2      0.500000
#      normal             0      0.586207
#                         1      0.241379
#                         3      0.068966
#                         2      0.068966
#                         4      0.034483
#      reversable defect  1      0.312500
#                         2      0.312500
#                         3      0.187500
#                         0      0.125000
#                         4      0.062500
# 2.0  fixed defect       4      0.250000
# ...

# %%
# Visualization
ht.groupby(['ca', 'thal'])['num'].value_counts(normalize=True).unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='ca,thal'>
